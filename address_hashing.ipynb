# %% [markdown]
# # Hash group

# %%
def get_bit(value, bit_index):
    return (value & (1 << bit_index)) >> bit_index

def get_bit_mask(value, bit_index):
    return (value & (1 << bit_index))

def get_hash2(value):
    return get_bit(value, 6) ^ get_bit(value, 7) ^ get_bit(value, 8) ^ get_bit(value, 9) ^ get_bit(value, 10) ^\
get_bit(value, 11) ^ get_bit(value, 12) ^ get_bit(value, 13) ^ get_bit(value, 14) ^ get_bit(value, 15) ^\
get_bit(value, 16) ^ get_bit(value, 17) ^ get_bit(value, 18) ^ get_bit(value, 19) ^ get_bit(value, 20) ^\
get_bit(value, 21) ^ get_bit(value, 22) ^ get_bit(value, 23) ^ get_bit(value, 24) ^ get_bit(value, 25) ^\
get_bit(value, 26) ^ get_bit(value, 27) ^ get_bit(value, 28) ^ get_bit(value, 29) ^ get_bit(value, 30) ^\
get_bit(value, 31) ^ get_bit(value, 32) ^ get_bit(value, 33) ^ get_bit(value, 34) ^ get_bit(value, 35) ^\
get_bit(value, 36) ^ get_bit(value, 37) ^ get_bit(value, 38) ^ get_bit(value, 39) ^ get_bit(value, 40) ^\
get_bit(value, 41) ^ get_bit(value, 42) ^ get_bit(value, 43) ^ get_bit(value, 44) ^ get_bit(value, 45) ^\
get_bit(value, 46) ^ get_bit(value, 47) ^ get_bit(value, 48) ^ get_bit(value, 49) ^ get_bit(value, 50) ^ get_bit(value, 51)


def get_hash4(value):
    return (get_bit(value, 6) ^ get_bit(value, 8) ^ get_bit(value, 10) ^\
get_bit(value, 12) ^ get_bit(value, 14) ^ get_bit(value, 16) ^ get_bit(value, 18) ^ get_bit(value, 20) ^\
get_bit(value, 22) ^ get_bit(value, 24) ^ get_bit(value, 26) ^\
get_bit(value, 28) ^ get_bit(value, 30) ^ get_bit(value, 32) ^ get_bit(value, 34) ^ get_bit(value, 36) ^\
get_bit(value, 38) ^ get_bit(value, 40) ^ get_bit(value, 42) ^ get_bit(value, 44) ^ get_bit(value, 46) ^\
get_bit(value, 48) ^ get_bit(value, 50)) | \
((get_bit(value, 7) ^ get_bit(value, 9) ^ get_bit(value, 11) ^ get_bit(value, 13) ^ get_bit(value, 15) ^\
get_bit(value, 17) ^ get_bit(value, 19) ^ get_bit(value, 21) ^ get_bit(value, 23) ^ get_bit(value, 25) ^\
get_bit(value, 27) ^ get_bit(value, 29) ^ get_bit(value, 31) ^ get_bit(value, 33) ^ get_bit(value, 35) ^\
get_bit(value, 37) ^ get_bit(value, 39) ^ get_bit(value, 41) ^ get_bit(value, 43) ^ get_bit(value, 45) ^\
get_bit(value, 47) ^ get_bit(value, 49) ^ get_bit(value, 51)) << 1)



def get_hash8(value):
    return  get_bit(value, 6) ^  get_bit(value, 9) ^ get_bit(value, 12) ^ get_bit(value, 15) ^\
get_bit(value, 18) ^ get_bit(value, 21) ^ get_bit(value, 24) ^ get_bit(value, 27) ^\
get_bit(value, 30) ^ get_bit(value, 33) ^ get_bit(value, 36) ^ get_bit(value, 39) ^\
get_bit(value, 42) ^ get_bit(value, 45) ^ get_bit(value, 48) ^ get_bit(value, 51) |\
((get_bit(value, 7) ^ get_bit(value, 10) ^ get_bit(value, 13) ^ get_bit(value, 16) ^\
get_bit(value, 19) ^ get_bit(value, 22) ^ get_bit(value, 25) ^ get_bit(value, 28) ^\
get_bit(value, 31) ^ get_bit(value, 34) ^ get_bit(value, 37) ^ get_bit(value, 40) ^\
get_bit(value, 43) ^ get_bit(value, 46) ^ get_bit(value, 49)) << 1) |\
((get_bit(value, 8) ^ get_bit(value, 11) ^ get_bit(value, 14) ^ get_bit(value, 17) ^\
get_bit(value, 20) ^ get_bit(value, 23) ^ get_bit(value, 26) ^ get_bit(value, 29) ^\
get_bit(value, 32) ^ get_bit(value, 35) ^ get_bit(value, 38) ^ get_bit(value, 41) ^\
get_bit(value, 44) ^ get_bit(value, 47) ^ get_bit(value, 50)) << 2)

# %%
def get_bits(value, low, high):
    bits = 0
    for i in range(low, high + 1):
        bits |= get_bit_mask(value, i)
    return bits

def get_bits_value(value, low, high):
    bits = 0
    for i in range(low, high + 1):
        bits |= get_bit_mask(value, i)
    return (bits >> low)

# %% [markdown]
# # Non-power-of 2 hashing
#     hash12[11:0] = {2’b00,Address[51:42]} ^ Address[41:30] ^ Address[29:18] ^ Address[17:6]
#
#     mod[11:0] = { (hash12[11]^hash12[0]), (hash12[10]^hash12[1]), (hash12[9]^hash12[2]),
# 		 (hash12[8]^hash12[3]),  (hash12[7]^hash12[4]), (hash12[6]^hash12[5]),
# 		hash12[5:0] }
#
# 	Offset[6:0] = (mod[11:0] * number_of_target_nodes) >> 12

# %% [markdown]
# # Hierarchical hashing
# First level of hashing
#
# Number of bits XOR’d = log2(4) = 2
# first_level[1:0] = 2’b11
#
# Second level of hashing
#
# n = 6 + log2(4) = 8
# Address’[51:6] = {(8-6)’b0, Address[51:8]} = 46’h80_80A0
#
# hash12[11:0] = 12’h000 ^ 12’h000 ^ 12’h808 ^ 12’h0A0 = 12’h8A8
#
# mod[11:0] = {1’b1, 1’b0, 1’b0, 1’b1, 1’b1, 1’b1, 6’b10_1000} = 12’h9E8
#
# second_level[6:0] = (12’h9E8 * ’h7) >> ’hC = 7’h4
#
# Final offset value
#
# Offset[6:0] = ( ’h3 * ’h7 ) + 7’h4 = 7’h19

# %%
def hash12(value):
    bits = 0
    bits = get_bits_value(value, 42, 51) ^ get_bits_value(value, 30, 41) ^ get_bits_value(value, 18, 29) ^ get_bits_value(value, 6, 17)
    return bits

def mode12(value):
    return ((get_bit(value, 11) ^ get_bit(value, 0)) << 11) | ((get_bit(value, 10) ^ get_bit(value, 1)) << 10) | \
((get_bit(value, 9) ^ get_bit(value, 2)) << 9) | ((get_bit(value, 8) ^ get_bit(value, 3)) << 8) | \
((get_bit(value, 7) ^ get_bit(value, 4)) << 7) | ((get_bit(value, 6) ^ get_bit(value, 5)) << 6) | get_bits_value(value, 0, 5)

def offset(value, n):
    return (value * n) >> 12

def NP2_index(value, n):
    return offset(mode12(hash12(value)) , n)

# %%
def cluster2_get_l1_index(value):
    return get_hash2(value)

def cluster4_get_l1_index(value):
    return get_hash4(value)

def cluster2_get_l2_index(value, hnfs):
    return NP2_index((get_bits_value(value, 7, 51) << 6), hnfs)

def cluster4_get_l2_index(value, hnfs):
    return NP2_index((get_bits_value(value, 8, 51) << 6), hnfs)

def cluster_off(l1, l2, n):
    return (l1 * n) + l2

def cluster2_get_index(value, hnfs):
    return cluster_off(cluster2_get_l1_index(value), cluster2_get_l2_index(value, hnfs), hnfs)

def cluster4_get_index(value, hnfs):
    return cluster_off(cluster4_get_l1_index(value), cluster4_get_l2_index(value, hnfs), hnfs)

# %%
print ("0x{:08x}".format(cluster4_get_l1_index(0x8080A0C0)))
# Out:
# 0x00000003

# %%
print ("0x{:08x}".format(cluster4_get_l2_index(0x8080A0C0, 7)))
# Out:
# 0x00000004

# %%
print ("0x{:08x}".format(cluster4_get_index(0x8080A0C0, 7)))
# Out:
# 0x00000019

# %%
print ("0x{:08x}".format(NP2_index(0x8080A0C0 , 18)))
# Out:
# 0x0000000c

# %% [markdown]
# # Power of 2 shutter
# # Bits range [13:6]
# * The highest bit removed is log2(number of HNFs) + 5
# * Number of bits to be stripped is log2(number of SNFs) below the highest bit
# * No bits need to be removed for 1 SNF

# %%
def de_hash2(value):
    return  ((get_bits_value(value, 6, 51) >> 1) << 6)

# %%
def de_hash4(value):
    return  ((get_bits_value(value, 6, 51) >> 2) << 6)

# %%
def de_hash8(value):
    return  ((get_bits(value, 6, 51) >> 3) << 6)

# %%
get_bits(0xc00, 8, 11)
# Out:
# 3072

# %%
print ("0x{:08x}".format(0xc00))
# Out:
# 0x00000c00

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import ctypes


colors=list(mcolors.TABLEAU_COLORS.keys())

x1 = [0]
x2 = [1]
x3 = [2]


cacheline = np.array([64])
addr = 0
lastbar = np.array([addr])

#add colors
#colors = ['#FF9999', '#00BFFF','#C1FFC1','#CAE1FF','#FFDEAD']
# The position of the bars on the x-axis

barWidth = 1
#plot bars
#plt.figure(figsize=(12,16))
fig, ax = plt.subplots(figsize = (12,16))

ax.set_xticks([0, 1, 2])

ax.set_xticklabels(["hash2", "hash4", "hash8"])


#plt.bar(x, cacheline, color=colors[1], edgecolor='white', label="0")
ytick = [addr]


while addr <= 0x600:
    plt.bar(x1, cacheline, bottom=np.array(lastbar),color=colors[get_hash2(addr)], edgecolor='white', label="hash2")
    plt.bar(x2, cacheline, bottom=np.array(lastbar),color=colors[get_hash4(addr)], edgecolor='white', label="hash4")
    plt.bar(x3, cacheline, bottom=np.array(lastbar),color=colors[get_hash8(addr)], edgecolor='white', label="hash8")
    ytick.append(addr)
    print ("0x{:08x} 0x{:08x}".format(addr, get_hash2(addr)))
    lastbar = lastbar + 64
    addr += 64

print ("{:08x}".format(addr))

legend_hg0 = mpatches.Patch(color=colors[0], label='hashgroup0')
legend_hg1 = mpatches.Patch(color=colors[1], label='hashgroup1')
legend_hg2 = mpatches.Patch(color=colors[2], label='hashgroup2')
legend_hg3 = mpatches.Patch(color=colors[3], label='hashgroup3')
legend_hg4 = mpatches.Patch(color=colors[4], label='hashgroup4')
legend_hg5 = mpatches.Patch(color=colors[5], label='hashgroup5')
legend_hg6 = mpatches.Patch(color=colors[6], label='hashgroup6')
legend_hg7 = mpatches.Patch(color=colors[7], label='hashgroup7')




plt.legend(handles=[legend_hg0, legend_hg1, legend_hg2, legend_hg3, legend_hg4, legend_hg5, legend_hg6, legend_hg7])
ax.set_yticks(ytick);
ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);
    
#plt.bar(x, tshirt, bottom=np.array(jeans), color=colors[1], edgecolor='white', width=barWidth, label='tshirt')
#plt.bar(x, formal_shirt, bottom=np.array(jeans)+np.array(tshirt), color=colors[2], edgecolor='white', width=barWidth, label='formal shirt')
plt.show()
# Out:
# 0x00000000 0x00000000
# 0x00000040 0x00000001
# 0x00000080 0x00000001
# 0x000000c0 0x00000000
# 0x00000100 0x00000001
# 0x00000140 0x00000000
# 0x00000180 0x00000000
# 0x000001c0 0x00000001
# 0x00000200 0x00000001
# 0x00000240 0x00000000
# 0x00000280 0x00000000
# 0x000002c0 0x00000001
# 0x00000300 0x00000000
# 0x00000340 0x00000001
# 0x00000380 0x00000001
# 0x000003c0 0x00000000
# 0x00000400 0x00000001
# 0x00000440 0x00000000
# 0x00000480 0x00000000
# 0x000004c0 0x00000001
# 0x00000500 0x00000000
# 0x00000540 0x00000001
# 0x00000580 0x00000001
# 0x000005c0 0x00000000
# 0x00000600 0x00000000
# 00000640

# %%
hex(de_hash4(0x00000180))
# Out:
# '0x40'

# %%
hex(de_hash2(0x00000180))
# Out:
# '0xc0'

# %%
colors=list(mcolors.TABLEAU_COLORS.keys())

x1 = [0]
x2 = [1]
x3 = [2]


cacheline = np.array([64])
addr = 0
lastbar = np.array([0])
lastddr = np.array([0])


de_hash_group0 = []
de_hash_group1 = []



#add colors
#colors = ['#FF9999', '#00BFFF','#C1FFC1','#CAE1FF','#FFDEAD']
# The position of the bars on the x-axis

barWidth = 1
#plot bars
#plt.figure(figsize=(12,16))
fig, ax = plt.subplots(figsize = (12,16))

ax2 = ax.twinx()  


ax.set_xticks([0, 1, 2])

ax.set_xticklabels(["hash2", "de-interleave"])


#plt.bar(x, cacheline, color=colors[1], edgecolor='white', label="0")
ytick = [0]
ytick2 = [0]

while addr <= 0x800:
    plt.bar(x1, cacheline, bottom=np.array(lastbar),color=colors[get_hash2(addr)],alpha = 0.9, width =0.8, edgecolor='white', label="hash2")
    ytick.append(addr)
    if get_hash2(addr) == 0:
        plt.bar(x2, cacheline, bottom=np.array(lastddr),color=colors[get_hash2(addr)],alpha=0.9, width =0.8, edgecolor='white', label="de-interleave")
        lastddr += 64
        l = mlines.Line2D([0, 1], [addr, de_hash2(addr)], color='black', marker='o', markersize=6, linestyle='--')
        print ("0x{:08x} 0x{:08x}".format(addr, de_hash2(addr)))
        ax.add_line(l)
        ytick2.append(de_hash2(addr))
    lastbar = lastbar + 64
    addr += 64
    



legend_hg0 = mpatches.Patch(color=colors[0], label='hashgroup0')
legend_hg1 = mpatches.Patch(color=colors[1], label='hashgroup1')





plt.legend(handles=[legend_hg0, legend_hg1])
ax.set_yticks(ytick);
ax2.set_yticks(ytick);

#ax2.set_yticks(np.linspace(ax.get_yticks()[0], ax.get_yticks()[-1], len(ax.get_yticks())))


ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);

ylabels2 = map(lambda t: '0x%08X' % int(t), ax2.get_yticks())    
ax2.set_yticklabels(ylabels2);

l = ax.get_ylim()
ax2.set_ylim(l)
l2 = ax2.get_ylim()



print (l)
print (l2)
    
#plt.bar(x, tshirt, bottom=np.array(jeans), color=colors[1], edgecolor='white', width=barWidth, label='tshirt')
#plt.bar(x, formal_shirt, bottom=np.array(jeans)+np.array(tshirt), color=colors[2], edgecolor='white', width=barWidth, label='formal shirt')
plt.show()
# Out:
# 0x00000000 0x00000000
# 0x000000c0 0x00000040
# 0x00000140 0x00000080
# 0x00000180 0x000000c0
# 0x00000240 0x00000100
# 0x00000280 0x00000140
# 0x00000300 0x00000180
# 0x000003c0 0x000001c0
# 0x00000440 0x00000200
# 0x00000480 0x00000240
# 0x00000500 0x00000280
# 0x000005c0 0x000002c0
# 0x00000600 0x00000300
# 0x000006c0 0x00000340
# 0x00000740 0x00000380
# 0x00000780 0x000003c0
# (0.0, 2048.0)
# (0.0, 2048.0)

# %%
colors=list(mcolors.TABLEAU_COLORS.keys())

x1 = [0]
x2 = [1]
x3 = [2]


cacheline = np.array([64])
addr = 0
lastbar = np.array([0])
lastddr = np.array([0])


de_hash_group0 = []
de_hash_group1 = []



#add colors
#colors = ['#FF9999', '#00BFFF','#C1FFC1','#CAE1FF','#FFDEAD']
# The position of the bars on the x-axis

barWidth = 1
#plot bars
#plt.figure(figsize=(12,16))
fig, ax = plt.subplots(figsize = (12,16))

ax2 = ax.twinx()  


ax.set_xticks([0, 1, 2])

ax.set_xticklabels(["hash4", "de-interleave"])


#plt.bar(x, cacheline, color=colors[1], edgecolor='white', label="0")
ytick = [0]
ytick2 = [0]

while addr <= 0x600:
    plt.bar(x1, cacheline, bottom=np.array(lastbar),color=colors[get_hash4(addr)],alpha = 0.9, width =0.8, edgecolor='white', label="hash2")
    ytick.append(addr)
    if get_hash4(addr) == 0:
        plt.bar(x2, cacheline, bottom=np.array(lastddr),color=colors[get_hash4(addr)],alpha=0.9, width =0.8, edgecolor='white', label="de-interleave")
        lastddr += 64
        l = mlines.Line2D([0, 1], [addr, de_hash4(addr)], color='black', marker='o', markersize=6, linestyle='--')
        print ("0x{:08x} 0x{:08x}".format(addr, de_hash4(addr)))
        ax.add_line(l)
        ytick2.append(de_hash4(addr))
    lastbar = lastbar + 64
    addr += 64
    



legend_hg0 = mpatches.Patch(color=colors[0], label='hashindex0')
legend_hg1 = mpatches.Patch(color=colors[1], label='hashindex1')
legend_hg2 = mpatches.Patch(color=colors[2], label='hashindex2')
legend_hg3 = mpatches.Patch(color=colors[3], label='hashindex3')






plt.legend(handles=[legend_hg0, legend_hg1, legend_hg2, legend_hg3])
ax.set_yticks(ytick);
ax2.set_yticks(ytick);

#ax2.set_yticks(np.linspace(ax.get_yticks()[0], ax.get_yticks()[-1], len(ax.get_yticks())))


ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);

ylabels2 = map(lambda t: '0x%08X' % int(t), ax2.get_yticks())    
ax2.set_yticklabels(ylabels2);

l = ax.get_ylim()
ax2.set_ylim(l)
l2 = ax2.get_ylim()



print (l)
print (l2)
    
#plt.bar(x, tshirt, bottom=np.array(jeans), color=colors[1], edgecolor='white', width=barWidth, label='tshirt')
#plt.bar(x, formal_shirt, bottom=np.array(jeans)+np.array(tshirt), color=colors[2], edgecolor='white', width=barWidth, label='formal shirt')
plt.show()
# Out:
# 0x00000000 0x00000000
# 0x00000140 0x00000040
# 0x00000280 0x00000080
# 0x000003c0 0x000000c0
# 0x00000440 0x00000100
# 0x00000500 0x00000140
# (0.0, 1536.0)
# (0.0, 1536.0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import ctypes

matplotlib.rcParams['font.size'] = 14.0

# Fixing random state for reproducibility
np.random.seed(19680801)


# create random data
data1 = np.random.randint(20, size=(4, 20)) * 64


data2 = np.arange(128) * 64

hashindex0 = []
hashindex1 = []
hashindex2 = []
hashindex3 = []


for addr in data2:
    if get_hash4(addr) == 0:
        hashindex0.append(addr)
    if get_hash4(addr) == 1:
        hashindex1.append(addr)
    if get_hash4(addr) == 2:
        hashindex2.append(addr)
    if get_hash4(addr) == 3:
        hashindex3.append(addr)
        
data1 = np.array([hashindex0, hashindex1, hashindex2, hashindex3])
        
# set different colors for each set of positions
colors1 = ['C{}'.format(i) for i in range(4)]

# set different line properties for each set of positions
# note that some overlap
lineoffsets1 = [0, 1, 2, 3]
linelengths1 = [1, 1, 1, 1]
linewidths1 = np.repeat(25, 4)


fig, ax = plt.subplots(figsize = (20,64))




legend_hg0 = mpatches.Patch(color=colors1[0], label='hashindex0')
legend_hg1 = mpatches.Patch(color=colors1[1], label='hashindex1')
legend_hg2 = mpatches.Patch(color=colors1[2], label='hashindex2')
legend_hg3 = mpatches.Patch(color=colors1[3], label='hashindex3')


ytick = data2

plt.legend(handles=[legend_hg0, legend_hg1, legend_hg2, legend_hg3])
ax.set_yticks(ytick);
ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);


ax.set_xticks([0, 1, 2, 3])

ax.set_xticklabels(["hashindex0", "hashindex1", "hashindex2", "hashindex3"])

ax.set_ylim(bottom=-64)

# create a horizontal plot
ax.eventplot(data1, colors=colors1, lineoffsets=lineoffsets1, linelengths=linelengths1, linewidths=linewidths1, orientation='vertical')

# create a vertical plot
#axs[1, 0].eventplot(data1, colors=colors1, lineoffsets=lineoffsets1,
                    #linelengths=linelengths1, orientation='vertical')


plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import ctypes

matplotlib.rcParams['font.size'] = 14.0

# Fixing random state for reproducibility
np.random.seed(19680801)


# create random data
data1 = np.random.randint(20, size=(4, 20)) * 64


data2 = np.arange(32) * 64

hashindex0 = []
hashindex1 = []
hashindex2 = []
hashindex3 = []


for addr in data2:
    if cluster2_get_index(addr, 2) == 0:
        hashindex0.append(addr)
    if cluster2_get_index(addr, 2) == 1:
        hashindex1.append(addr)
    if cluster2_get_index(addr, 2) == 2:
        hashindex2.append(addr)
    if cluster2_get_index(addr, 2) == 3:
        hashindex3.append(addr)
        
data1 = np.array([hashindex0, hashindex1, hashindex2, hashindex3])
        
# set different colors for each set of positions
colors1 = ['C{}'.format(i) for i in range(4)]

# set different line properties for each set of positions
# note that some overlap
lineoffsets1 = [0, 1, 2, 3]
linelengths1 = [1, 1, 1, 1]
linewidths1 = np.repeat(25, 4)


fig, ax = plt.subplots(figsize = (20,16))




legend_hg0 = mpatches.Patch(color=colors1[0], label='hashindex0')
legend_hg1 = mpatches.Patch(color=colors1[1], label='hashindex1')
legend_hg2 = mpatches.Patch(color=colors1[2], label='hashindex2')
legend_hg3 = mpatches.Patch(color=colors1[3], label='hashindex3')


ytick = data2

plt.legend(handles=[legend_hg0, legend_hg1, legend_hg2, legend_hg3])
ax.set_yticks(ytick);
ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);


ax.set_xticks([0, 1, 2, 3])

ax.set_xticklabels(["hashindex0", "hashindex1", "hashindex2", "hashindex3"])

ax.set_ylim(bottom=-64)

# create a horizontal plot
ax.eventplot(data1, colors=colors1, lineoffsets=lineoffsets1, linelengths=linelengths1, linewidths=linewidths1, orientation='vertical')

# create a vertical plot
#axs[1, 0].eventplot(data1, colors=colors1, lineoffsets=lineoffsets1,
                    #linelengths=linelengths1, orientation='vertical')


plt.show()

# %%
data1
# Out:
# array([[   0,  320,  576,  768, 1088, 1280, 1536, 1856, 2112, 2304, 2560,
#         2880, 3072, 3392, 3648, 3840, 4160, 4352, 4608, 4928, 5120, 5440,
#         5696, 5888, 6144, 6464, 6720, 6912, 7232, 7424, 7680, 8000],
#        [ 192,  384,  640,  960, 1152, 1472, 1728, 1920, 2176, 2496, 2752,
#         2944, 3264, 3456, 3712, 4032, 4224, 4544, 4800, 4992, 5312, 5504,
#         5760, 6080, 6336, 6528, 6784, 7104, 7296, 7616, 7872, 8064],
#        [  64,  256,  512,  832, 1024, 1344, 1600, 1792, 2048, 2368, 2624,
#         2816, 3136, 3328, 3584, 3904, 4096, 4416, 4672, 4864, 5184, 5376,
#         5632, 5952, 6208, 6400, 6656, 6976, 7168, 7488, 7744, 7936],
#        [ 128,  448,  704,  896, 1216, 1408, 1664, 1984, 2240, 2432, 2688,
#         3008, 3200, 3520, 3776, 3968, 4288, 4480, 4736, 5056, 5248, 5568,
#         5824, 6016, 6272, 6592, 6848, 7040, 7360, 7552, 7808, 8128]])

# %%
data1
# Out:
# array([[   0,  320,  576,  768, 1088, 1280, 1536, 1856, 2112, 2304, 2560,
#         2880, 3072, 3392, 3648, 3840, 4160, 4352, 4608, 4928, 5120, 5440,
#         5696, 5888, 6144, 6464, 6720, 6912, 7232, 7424, 7680, 8000],
#        [ 192,  384,  640,  960, 1152, 1472, 1728, 1920, 2176, 2496, 2752,
#         2944, 3264, 3456, 3712, 4032, 4224, 4544, 4800, 4992, 5312, 5504,
#         5760, 6080, 6336, 6528, 6784, 7104, 7296, 7616, 7872, 8064],
#        [  64,  256,  512,  832, 1024, 1344, 1600, 1792, 2048, 2368, 2624,
#         2816, 3136, 3328, 3584, 3904, 4096, 4416, 4672, 4864, 5184, 5376,
#         5632, 5952, 6208, 6400, 6656, 6976, 7168, 7488, 7744, 7936],
#        [ 128,  448,  704,  896, 1216, 1408, 1664, 1984, 2240, 2432, 2688,
#         3008, 3200, 3520, 3776, 3968, 4288, 4480, 4736, 5056, 5248, 5568,
#         5824, 6016, 6272, 6592, 6848, 7040, 7360, 7552, 7808, 8128]])

# %%
linewidths
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-70f29d82e3ba> in <module>()
# ----> 1 linewidths
#
# NameError: name 'linewidths' is not defined

# %%
data2 = np.arange(100) * 64

# %%
data2
# Out:
# array([   0,   64,  128,  192,  256,  320,  384,  448,  512,  576,  640,
#         704,  768,  832,  896,  960, 1024, 1088, 1152, 1216, 1280, 1344,
#        1408, 1472, 1536, 1600, 1664, 1728, 1792, 1856, 1920, 1984, 2048,
#        2112, 2176, 2240, 2304, 2368, 2432, 2496, 2560, 2624, 2688, 2752,
#        2816, 2880, 2944, 3008, 3072, 3136, 3200, 3264, 3328, 3392, 3456,
#        3520, 3584, 3648, 3712, 3776, 3840, 3904, 3968, 4032, 4096, 4160,
#        4224, 4288, 4352, 4416, 4480, 4544, 4608, 4672, 4736, 4800, 4864,
#        4928, 4992, 5056, 5120, 5184, 5248, 5312, 5376, 5440, 5504, 5568,
#        5632, 5696, 5760, 5824, 5888, 5952, 6016, 6080, 6144, 6208, 6272,
#        6336])

# %%
hashindex0 = []
hashindex1 = []
hashindex2 = []
hashindex3 = []


for addr in data2:
    if get_hash4(addr) == 0:
        hashindex0.append(addr)
    if get_hash4(addr) == 1:
        hashindex1.append(addr)
    if get_hash4(addr) == 2:
        hashindex2.append(addr)
    if get_hash4(addr) == 3:
        hashindex3.append(addr)

# %%
hashindex0
# Out:
# [0,
#  320,
#  640,
#  960,
#  1088,
#  1280,
#  1728,
#  1920,
#  2176,
#  2496,
#  2560,
#  2880,
#  3264,
#  3456,
#  3648,
#  3840,
#  4160,
#  4352,
#  4800,
#  4992,
#  5120,
#  5440,
#  5760,
#  6080,
#  6336]

# %%
hashindex1
# Out:
# [64,
#  256,
#  704,
#  896,
#  1024,
#  1344,
#  1664,
#  1984,
#  2240,
#  2432,
#  2624,
#  2816,
#  3200,
#  3520,
#  3584,
#  3904,
#  4096,
#  4416,
#  4736,
#  5056,
#  5184,
#  5376,
#  5824,
#  6016,
#  6272]

# %%
hashindex2
# Out:
# [128,
#  448,
#  512,
#  832,
#  1216,
#  1408,
#  1600,
#  1792,
#  2048,
#  2368,
#  2688,
#  3008,
#  3136,
#  3328,
#  3776,
#  3968,
#  4288,
#  4480,
#  4672,
#  4864,
#  5248,
#  5568,
#  5632,
#  5952,
#  6208]

# %%
hashindex3
# Out:
# [192,
#  384,
#  576,
#  768,
#  1152,
#  1472,
#  1536,
#  1856,
#  2112,
#  2304,
#  2752,
#  2944,
#  3072,
#  3392,
#  3712,
#  4032,
#  4224,
#  4544,
#  4608,
#  4928,
#  5312,
#  5504,
#  5696,
#  5888,
#  6144]

# %%
linewidths
# Out:
# array([64, 64, 64, 64])

# %%
data1
# Out:
# array([[ 768,  832,  384,  128,  128,  192, 1088,  256,  640, 1152,  704,
#          512,  320,  704,  192,  320, 1024,  576, 1216,  192],
#        [1152,   64,    0, 1216,    0,  320,    0, 1088,  384, 1216,  128,
#          640,  640,  704,  960,  576,  448,  192,  384,  640],
#        [ 640,  192,  960,  448,  896, 1216, 1024,  640,   64,  320,  384,
#           64,  512,  128,    0, 1088,   64,  320,  768,  640],
#        [   0,  768,  832,  320,  704,  448, 1152,    0,  384,    0,  320,
#         1152, 1088, 1216, 1088,    0,  576,  192,  576,  768]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import ctypes

matplotlib.rcParams['font.size'] = 14.0

# Fixing random state for reproducibility
np.random.seed(19680801)


# create random data
data1 = np.random.randint(20, size=(4, 20)) * 64


data2 = np.arange(32) * 64

hashindex0 = []
hashindex1 = []
hashindex2 = []
hashindex3 = []
hashindex4 = []
hashindex5 = []
hashindex6 = []
hashindex7 = []

for addr in data2:
    if get_hash8(addr) == 0:
        hashindex0.append(addr)
    if get_hash8(addr) == 1:
        hashindex1.append(addr)
    if get_hash8(addr) == 2:
        hashindex2.append(addr)
    if get_hash8(addr) == 3:
        hashindex3.append(addr)
    if get_hash8(addr) == 4:
        hashindex4.append(addr)
    if get_hash8(addr) == 5:
        hashindex5.append(addr)
    if get_hash8(addr) == 6:
        hashindex6.append(addr)
    if get_hash8(addr) == 7:
        hashindex7.append(addr)
        
data1 = np.array([hashindex0, hashindex1, hashindex2, hashindex3, hashindex4, hashindex5, hashindex6, hashindex7])
        
# set different colors for each set of positions
colors1 = ['C{}'.format(i) for i in range(8)]

# set different line properties for each set of positions
# note that some overlap
lineoffsets1 = [0, 1, 2, 3, 4, 5, 6, 7]
linelengths1 = [1, 1, 1, 1, 1, 1, 1 ,1]
linewidths1 = np.repeat(25, 8)


fig, ax = plt.subplots(figsize = (20,16))




legend_hg0 = mpatches.Patch(color=colors1[0], label='hashindex0')
legend_hg1 = mpatches.Patch(color=colors1[1], label='hashindex1')
legend_hg2 = mpatches.Patch(color=colors1[2], label='hashindex2')
legend_hg3 = mpatches.Patch(color=colors1[3], label='hashindex3')
legend_hg4 = mpatches.Patch(color=colors1[0], label='hashindex4')
legend_hg5 = mpatches.Patch(color=colors1[1], label='hashindex5')
legend_hg6 = mpatches.Patch(color=colors1[2], label='hashindex6')
legend_hg7 = mpatches.Patch(color=colors1[3], label='hashindex7')


ytick = data2

plt.legend(handles=[legend_hg0, legend_hg1, legend_hg2, legend_hg3, legend_hg4, legend_hg5, legend_hg6, legend_hg7])
ax.set_yticks(ytick);
ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);


ax.set_xticks([0, 1, 2, 3, 4, 5, 6, 7])

ax.set_xticklabels(["hashindex0", "hashindex1", "hashindex2", "hashindex3", "hashindex4", "hashindex5", "hashindex6", "hashindex7"])

ax.set_ylim(bottom=-64)

# create a horizontal plot
ax.eventplot(data1, colors=colors1, lineoffsets=lineoffsets1, linelengths=linelengths1, linewidths=linewidths1, orientation='vertical')

# create a vertical plot
#axs[1, 0].eventplot(data1, colors=colors1, lineoffsets=lineoffsets1,
                    #linelengths=linelengths1, orientation='vertical')


plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import ctypes

matplotlib.rcParams['font.size'] = 14.0

# Fixing random state for reproducibility
np.random.seed(19680801)


# create random data
data1 = np.random.randint(20, size=(4, 20)) * 64


data2 = np.arange(32) * 64

hashindex0 = []
hashindex1 = []
hashindex2 = []
hashindex3 = []
hashindex4 = []
hashindex5 = []
hashindex6 = []
hashindex7 = []

for addr in data2:
    if cluster2_get_index(addr, 4) == 0:
        hashindex0.append(addr)
    if cluster2_get_index(addr, 4) == 1:
        hashindex1.append(addr)
    if cluster2_get_index(addr, 4) == 2:
        hashindex2.append(addr)
    if cluster2_get_index(addr, 4) == 3:
        hashindex3.append(addr)
    if cluster2_get_index(addr, 4) == 4:
        hashindex4.append(addr)
    if cluster2_get_index(addr, 4) == 5:
        hashindex5.append(addr)
    if cluster2_get_index(addr, 4) == 6:
        hashindex6.append(addr)
    if cluster2_get_index(addr, 4) == 7:
        hashindex7.append(addr)
        
data1 = np.array([hashindex0, hashindex1, hashindex2, hashindex3, hashindex4, hashindex5, hashindex6, hashindex7])
        
# set different colors for each set of positions
colors1 = ['C{}'.format(i) for i in range(8)]

# set different line properties for each set of positions
# note that some overlap
lineoffsets1 = [0, 1, 2, 3, 4, 5, 6, 7]
linelengths1 = [1, 1, 1, 1, 1, 1, 1 ,1]
linewidths1 = np.repeat(25, 8)


fig, ax = plt.subplots(figsize = (20,16))




legend_hg0 = mpatches.Patch(color=colors1[0], label='hashindex0 C0')
legend_hg1 = mpatches.Patch(color=colors1[1], label='hashindex1 C0')
legend_hg2 = mpatches.Patch(color=colors1[2], label='hashindex2 C0')
legend_hg3 = mpatches.Patch(color=colors1[3], label='hashindex3 C0')
legend_hg4 = mpatches.Patch(color=colors1[0], label='hashindex4 C1')
legend_hg5 = mpatches.Patch(color=colors1[1], label='hashindex5 C1')
legend_hg6 = mpatches.Patch(color=colors1[2], label='hashindex6 C1')
legend_hg7 = mpatches.Patch(color=colors1[3], label='hashindex7 C1')


ytick = data2

plt.legend(handles=[legend_hg0, legend_hg1, legend_hg2, legend_hg3, legend_hg4, legend_hg5, legend_hg6, legend_hg7])
ax.set_yticks(ytick);
ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);


ax.set_xticks([0, 1, 2, 3, 4, 5, 6, 7])

ax.set_xticklabels(["hashindex0", "hashindex1", "hashindex2", "hashindex3", "hashindex4", "hashindex5", "hashindex6", "hashindex7"])

ax.set_ylim(bottom=-64)

# create a horizontal plot
ax.eventplot(data1, colors=colors1, lineoffsets=lineoffsets1, linelengths=linelengths1, linewidths=linewidths1, orientation='vertical')

# create a vertical plot
#axs[1, 0].eventplot(data1, colors=colors1, lineoffsets=lineoffsets1,
                    #linelengths=linelengths1, orientation='vertical')


plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import ctypes

matplotlib.rcParams['font.size'] = 14.0

# Fixing random state for reproducibility
np.random.seed(19680801)


# create random data
data1 = np.random.randint(20, size=(4, 20)) * 64


data2 = np.arange(32) * 64

hashindex0 = []
hashindex1 = []
hashindex2 = []
hashindex3 = []
hashindex4 = []
hashindex5 = []
hashindex6 = []
hashindex7 = []

for addr in data2:
    if cluster4_get_index(addr, 2) == 0:
        hashindex0.append(addr)
    if cluster4_get_index(addr, 2) == 1:
        hashindex1.append(addr)
    if cluster4_get_index(addr, 2) == 2:
        hashindex2.append(addr)
    if cluster4_get_index(addr, 2) == 3:
        hashindex3.append(addr)
    if cluster4_get_index(addr, 2) == 4:
        hashindex4.append(addr)
    if cluster4_get_index(addr, 2) == 5:
        hashindex5.append(addr)
    if cluster4_get_index(addr, 2) == 6:
        hashindex6.append(addr)
    if cluster4_get_index(addr, 2) == 7:
        hashindex7.append(addr)
        
data1 = np.array([hashindex0, hashindex1, hashindex2, hashindex3, hashindex4, hashindex5, hashindex6, hashindex7])
        
# set different colors for each set of positions
colors1 = ['C{}'.format(i) for i in range(8)]

# set different line properties for each set of positions
# note that some overlap
lineoffsets1 = [0, 1, 2, 3, 4, 5, 6, 7]
linelengths1 = [1, 1, 1, 1, 1, 1, 1 ,1]
linewidths1 = np.repeat(25, 8)


fig, ax = plt.subplots(figsize = (20,16))




legend_hg0 = mpatches.Patch(color=colors1[0], label='hashindex0 C0')
legend_hg1 = mpatches.Patch(color=colors1[1], label='hashindex1 C0')
legend_hg2 = mpatches.Patch(color=colors1[2], label='hashindex2 C1')
legend_hg3 = mpatches.Patch(color=colors1[3], label='hashindex3 C1')
legend_hg4 = mpatches.Patch(color=colors1[0], label='hashindex4 C2')
legend_hg5 = mpatches.Patch(color=colors1[1], label='hashindex5 C2')
legend_hg6 = mpatches.Patch(color=colors1[2], label='hashindex6 C3')
legend_hg7 = mpatches.Patch(color=colors1[3], label='hashindex7 C3')


ytick = data2

plt.legend(handles=[legend_hg0, legend_hg1, legend_hg2, legend_hg3, legend_hg4, legend_hg5, legend_hg6, legend_hg7])
ax.set_yticks(ytick);
ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);


ax.set_xticks([0, 1, 2, 3, 4, 5, 6, 7])

ax.set_xticklabels(["hashindex0", "hashindex1", "hashindex2", "hashindex3", "hashindex4", "hashindex5", "hashindex6", "hashindex7"])

ax.set_ylim(bottom=-64)

# create a horizontal plot
ax.eventplot(data1, colors=colors1, lineoffsets=lineoffsets1, linelengths=linelengths1, linewidths=linewidths1, orientation='vertical')

# create a vertical plot
#axs[1, 0].eventplot(data1, colors=colors1, lineoffsets=lineoffsets1,
                    #linelengths=linelengths1, orientation='vertical')


plt.show()

# %%
import matplotlib.pyplot as plt

from matplotlib import cm
from numpy import linspace

start = 0.0
stop = 1.0
number_of_lines= 50
cm_subsection = linspace(start, stop, number_of_lines) 

colors = [ cm.hot(x) for x in cm_subsection ]

for i, color in enumerate(colors):
    plt.axhline(i, color=color)

plt.ylabel('Line Number')
plt.show()

# %% [markdown]
# # sudo /home/steven/bin/perf record -e arm_spe_0/ts_enable=1,pa_enable=1,pct_enable=1,load_filter=1,store_filter=1, jitter=1/ ./bw_mem -P 1 1G rdwr
# #  sudo /home/steven/bin/perf report -D > spe_buf.txt

# %%
! grep 'PA ' spe_buf.txt > spe_pa.txt

# %%
# !awk '{print $13,$14}' spe_pa.txt > spe_pa.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("spe_pa.csv", names=['PA', 'NS'], header = None, sep=' ')

# %%
df.head(5)
# Out:
#              PA    NS
# 0    0xf337c340  ns=1
# 1  0x8083858045  ns=1
# 2  0x808cc93040  ns=1
# 3  0x8088b966e0  ns=1
# 4  0x808973fbc0  ns=1

# %%
df.PA = df.PA.apply(lambda x: int(x, 16))

# %%
alignment = 64
df['PA_BASE'] = df['PA'] - df['PA'] % alignment

# %%
df.head(5)
# Out:
#              PA    NS       PA_BASE
# 0    4080517952  ns=1    4080517952
# 1  556534319732  ns=1  556534319680
# 2  556534319312  ns=1  556534319296
# 3  556534319176  ns=1  556534319168
# 4    4083649288  ns=1    4083649280

# %%
df['PA_BASE'] = df['PA_BASE'].astype(int)

# %%
alignment = 1024 * 1024 * 128
df['PA_BASE_128M'] = df['PA'] / alignment
df['PA_BASE_128M'] = df['PA_BASE_128M'].astype(int)

# %%
df['hashindex'] = df['PA'].apply(lambda x: get_hash4(x))

# %%
alignment = 1024 * 1024 * 1024 

df['ddr'] = df['PA'].apply(lambda x: (x - alignment*510) if (x >= alignment*512) else (x - alignment*2))

# %%
df.head(100)
# Out:
#               PA    NS  hashindex
# 0     4080517952  ns=1          3
# 1   551962378309  ns=1          2
# 2   552117809216  ns=1          1
# 3   552049665760  ns=1          3
# 4   552061893568  ns=1          0
# 5   552014330256  ns=1          3
# 6   583610064488  ns=1          1
# 7   552049664872  ns=1          1
# 8   551993686248  ns=1          2
# 9   565186171392  ns=1          2
# 10  552014329680  ns=1          1
# 11  552014329472  ns=1          3
# 12  552014330016  ns=1          2
# 13  552014329760  ns=1          2
# 14  552014329824  ns=1          3
# 15  552014329648  ns=1          0
# 16  564703908400  ns=1          0
# 17  555090874900  ns=1          2
# 18  565186174520  ns=1          1
# 19  552014330208  ns=1          0
# 20  551964784288  ns=1          1
# 21  551993685808  ns=1          1
# 22  552138499360  ns=1          1
# 23  565183857336  ns=1          2
# 24  552014330352  ns=1          2
# 25  551993686200  ns=1          3
# ...

# %%
df['PA_BASE_128M'].max()
# Out:
# 4351

# %%
df.groupby("hashindex").size().plot(kind='barh', figsize = (12,8))

# %%
dfg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-dac986efdff6> in <module>()
# ----> 1 dfg
#
# NameError: name 'dfg' is not defined

# %%
data = df['PA_BASE_2M']

# %%
data.reshape((4,4))

# %%
data1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import ctypes
from matplotlib import cm



data = np.zeros((1024 * 8))

for pa in df['PA_BASE_128M']:
    data[pa] =  data[pa] + 1

#data = data.reshape((1024,1024))
#data = np.random.rand(512, 512)


data = (data - np.min(data)) / (np.max(data) - np.min(data))

data = data.reshape((256,32))

data1,data2 = np.split(data, 2)

fig, ax = plt.subplots(figsize = (18,64))
im = ax.imshow(data1, cmap=plt.get_cmap('hot'))

# %%
fig, ax = plt.subplots(figsize = (18,64))
im = ax.imshow(data2, cmap=plt.get_cmap('hot'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-c9e7b8a213e4> in <module>()
#       1 fig, ax = plt.subplots(figsize = (18,64))
# ----> 2 im = ax.imshow(data2, cmap=plt.get_cmap('hot'))
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1716                     warnings.warn(msg % (label_namer, func.__name__),
#    1717                                   RuntimeWarning, stacklevel=2)
# -> 1718             return func(ax, *args, **kwargs)
#    1719         pre_doc = inner.__doc__
#    1720         if pre_doc is None:
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5125                               resample=resample, **kwargs)
#    5126
# ...

# %%
data.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-8637789457d2> in <module>()
# ----> 1 data.max()
#
# NameError: name 'data' is not defined

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import ctypes

matplotlib.rcParams['font.size'] = 14.0

# Fixing random state for reproducibility
np.random.seed(19680801)


# create random data
data1 = np.random.randint(20, size=(4, 20)) * 64

data2 = df['PA_BASE'].values

hashindex0 = []
hashindex1 = []
hashindex2 = []
hashindex3 = []


for addr in data2:
    if get_hash4(addr) == 0:
        hashindex0.append(addr)
    if get_hash4(addr) == 1:
        hashindex1.append(addr)
    if get_hash4(addr) == 2:
        hashindex2.append(addr)
    if get_hash4(addr) == 3:
        hashindex3.append(addr)

        
data1 = np.array([hashindex0, hashindex1, hashindex2, hashindex3])
        
# set different colors for each set of positions
colors1 = ['C{}'.format(i) for i in range(4)]

# set different line properties for each set of positions
# note that some overlap
lineoffsets1 = [0, 1, 2, 3]
linelengths1 = [1, 1, 1, 1]
linewidths1 = np.repeat(25, 4)


fig, ax = plt.subplots(figsize = (20,64))




legend_hg0 = mpatches.Patch(color=colors1[0], label='hashindex0')
legend_hg1 = mpatches.Patch(color=colors1[1], label='hashindex1')
legend_hg2 = mpatches.Patch(color=colors1[2], label='hashindex2')
legend_hg3 = mpatches.Patch(color=colors1[3], label='hashindex3')



ytick = data2

plt.legend(handles=[legend_hg0, legend_hg1, legend_hg2, legend_hg3])
ax.set_yticks(ytick);
ylabels = map(lambda t: '0x%08X' % int(t), ax.get_yticks())    
ax.set_yticklabels(ylabels);


ax.set_xticks([0, 1, 2, 3])

ax.set_xticklabels(["hashindex0", "hashindex1", "hashindex2", "hashindex3"])

ax.set_ylim(bottom=-64)

# create a horizontal plot
ax.eventplot(data1, colors=colors1, lineoffsets=lineoffsets1, linelengths=linelengths1, linewidths=linewidths1, orientation='vertical')

# create a vertical plot
#axs[1, 0].eventplot(data1, colors=colors1, lineoffsets=lineoffsets1,
                    #linelengths=linelengths1, orientation='vertical')


plt.show()
